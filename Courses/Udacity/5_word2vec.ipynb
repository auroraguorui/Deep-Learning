# %% [markdown]
# # Deep Learning
# ### Assignment 5
# The goal of this assignment is to train a Word2Vec skip-gram model over Text8 data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
words[:50]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english',
#  'revolution',
#  'and',
#  'the',
#  'sans',
#  'culottes',
#  'of',
#  'the',
#  'french',
#  'revolution',
#  'whilst',
#  'the',
#  'term',
#  'is',
#  'still',
#  'used',
#  'in',
#  'a',
#  'pejorative',
#  'way',
#  'to',
#  'describe',
#  'any',
#  'act',
#  'that',
#  'used',
#  'violent',
#  'means',
#  'to',
#  'destroy',
#  'the']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
print(len(data))
print(len(dictionary))
print(len(reverse_dictionary))
# Out:
# 17005207
# 50000
# 50000

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

# %%
print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'a', 'originated', 'originated', 'as', 'term', 'of']

# %% [markdown]
# ----
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

# %%
with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)


  print(embed.dtype)
  print(softmax_weights.dtype)
  print(softmax_biases.dtype),
  print(embed.dtype)
  print(train_labels.dtype)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# <dtype: 'float32'>
# <dtype: 'float32_ref'>
# <dtype: 'float32_ref'>
# <dtype: 'float32'>
# <dtype: 'int32'>

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.926834
# Nearest to or: elastic, lenat, toy, achaea, written, harpists, glas, lapsed,
# Nearest to as: congratulations, haggis, cooperative, declarations, halogen, microchip, sulfur, stab,
# Nearest to these: vuoksi, prerogatives, tren, luthier, bathed, leningrad, tansley, kayaking,
# Nearest to four: spaces, sensual, ha, congolese, evaporated, nosferatu, bodhisattvas, bullies,
# Nearest to all: ange, laypeople, freehold, relate, chocolate, adonai, kao, stopped,
# Nearest to two: espionage, im, uruguayan, carly, sauk, commuting, only, ley,
# Nearest to often: pretenders, scaffold, postulated, amc, benoit, presume, klein, crannog,
# Nearest to used: photosynthetic, sarajevo, heracles, catering, donuts, conservancy, portability, aeschylus,
# Nearest to called: misrepresenting, current, peril, elected, stephens, responses, improvised, geer,
# Nearest to i: jacinto, ritter, materiality, vaginal, ibsen, hypostasis, lio, recommendation,
# Nearest to zero: pattern, ether, vermont, constraint, postures, sentient, comptroller, rearden,
# Nearest to no: traditionalist, adventist, youthful, iupac, fornax, unrecorded, encrusted, logistic,
# Nearest to into: unwanted, overtaken, snp, lathes, milestones, hui, intakes, hygiene,
# Nearest to they: disruptive, richard, preferably, prose, typhoons, scot, heaped, outlining,
# Nearest to at: disliked, blanco, parakeet, minimize, dwarf, publicise, jealousy, labiodental,
# Nearest to time: noise, contralto, gymnastics, borel, macaroni, immunoglobulin, lira, constrained,
# Average loss at step 2000: 4.368350
# Average loss at step 4000: 3.871729
# Average loss at step 6000: 3.789216
# Average loss at step 8000: 3.686419
# Average loss at step 10000: 3.617510
# Nearest to or: and, elbing, hires, donny, nessie, manifesting, pouches, huldrych,
# Nearest to as: vim, by, ching, peirce, is, rothbard, saxons, baudelaire,
# Nearest to these: tren, bathed, some, prerogatives, many, francs, are, fulfilling,
# Nearest to four: six, seven, five, three, eight, zero, two, nine,
# Nearest to all: chocolate, format, inactive, relate, laypeople, equitable, inquisitor, computations,
# Nearest to two: three, five, four, one, eight, six, nine, seven,
# Nearest to often: presume, benoit, scaffold, prevalent, postulated, virtuosity, it, heller,
# Nearest to used: alchemical, donuts, known, semigroup, find, heracles, photosynthetic, sarajevo,
# Nearest to called: includes, sill, aleksei, pardons, occ, xiv, geer, leper,
# Nearest to i: ritter, literatures, materiality, hypostasis, chords, lio, recommendation, g,
# Nearest to zero: five, seven, six, eight, nine, four, three, two,
# Nearest to no: elite, traditionalist, replicas, iupac, adventist, huck, elevations, unrecorded,
# Nearest to into: handball, overtaken, breeding, with, on, byrd, iit, milestones,
# Nearest to they: he, there, humanists, prose, indeed, adsorption, colorful, she,
# Nearest to at: in, disliked, of, during, on, transatlantic, after, seebeck,
# Nearest to time: noise, gymnastics, xxiv, contralto, lira, gait, night, insect,
# Average loss at step 12000: 3.605317
# Average loss at step 14000: 3.567433
# Average loss at step 16000: 3.410884
# Average loss at step 18000: 3.459425
# Average loss at step 20000: 3.543265
# Nearest to or: and, than, elbing, rattus, pohnpei, ergodic, involve, seafood,
# Nearest to as: zimbabwean, battalions, tireless, malone, bully, guadalupe, ching, thrives,
# Nearest to these: some, many, tren, burdened, religious, which, such, all,
# Nearest to four: six, three, five, eight, seven, two, nine, zero,
# Nearest to all: some, use, computations, these, chocolate, twenty, many, expunged,
# Nearest to two: three, four, five, one, six, seven, eight, zero,
# Nearest to often: generally, usually, also, sometimes, scaffold, presume, virtuosity, prevalent,
# Nearest to used: known, written, found, semigroup, alchemical, formed, published, ravine,
# Nearest to called: sill, includes, occ, aleksei, varicella, pardons, merrick, elected,
# Nearest to i: ii, ritter, transnational, we, g, earthworks, eve, lieutenants,
# Nearest to zero: five, six, four, seven, three, nine, eight, two,
# Nearest to no: motherhood, elite, a, bogside, any, salem, sugarcubes, replicas,
# Nearest to into: handball, from, overtaken, byrd, with, datatype, during, iit,
# Nearest to they: he, there, we, it, not, she, indeed, colorful,
# Nearest to at: in, from, prefaces, during, on, disliked, after, through,
# Nearest to time: period, noise, night, xxiv, felonies, borel, gymnastics, insect,
# Average loss at step 22000: 3.502344
# Average loss at step 24000: 3.486166
# Average loss at step 26000: 3.482608
# Average loss at step 28000: 3.478681
# Average loss at step 30000: 3.505524
# Nearest to or: and, pohnpei, hlich, elbing, private, than, honorary, arrays,
# Nearest to as: by, tireless, rothbard, fliers, boxer, formerly, resilient, ribbons,
# Nearest to these: some, many, those, burdened, tren, such, mahindra, are,
# Nearest to four: five, six, eight, seven, three, nine, two, zero,
# Nearest to all: some, these, thinner, computations, presides, chocolate, twenty, expunged,
# Nearest to two: four, three, one, five, seven, six, eight, zero,
# Nearest to often: usually, sometimes, generally, commonly, also, widely, charges, scaffold,
# Nearest to used: known, written, found, published, regarded, described, referred, appointees,
# Nearest to called: sill, includes, varicella, spheroidal, merrick, occ, imperfect, richmond,
# Nearest to i: ii, we, g, ritter, transnational, tippit, update, speedup,
# Nearest to zero: five, seven, eight, four, six, nine, three, two,
# Nearest to no: any, a, little, tsuka, envoys, than, nicea, cyclists,
# Nearest to into: from, handball, under, overtaken, sada, byrd, inner, after,
# Nearest to they: there, we, he, it, she, you, not, these,
# Nearest to at: in, during, on, prefaces, disliked, under, after, kach,
# Nearest to time: period, night, noise, xxiv, evo, borel, day, contralto,
# Average loss at step 32000: 3.504058
# Average loss at step 34000: 3.492526
# Average loss at step 36000: 3.455834
# Average loss at step 38000: 3.301450
# Average loss at step 40000: 3.429671
# Nearest to or: than, and, excelling, elbing, any, arrays, circling, rather,
# Nearest to as: rothbard, ching, ribbons, ethologists, supper, collar, bully, battalions,
# Nearest to these: many, some, those, such, mahindra, which, they, both,
# Nearest to four: six, three, seven, five, eight, nine, two, zero,
# Nearest to all: some, twenty, those, both, interfered, any, aidan, entrant,
# Nearest to two: three, four, one, seven, six, five, eight, zero,
# Nearest to often: usually, sometimes, generally, commonly, also, which, still, widely,
# Nearest to used: known, found, referred, written, regarded, defined, described, available,
# Nearest to called: sill, spheroidal, varicella, hatfield, now, repairing, seaton, dimensionless,
# Nearest to i: we, ii, you, they, g, robotech, ritter, modalities,
# Nearest to zero: five, seven, nine, eight, six, four, three, two,
# Nearest to no: any, than, nicea, gir, cline, little, bogside, tsuka,
# Nearest to into: handball, from, across, further, under, overtaken, through, reginald,
# Nearest to they: we, there, he, you, not, she, it, these,
# Nearest to at: during, on, kach, in, quintessence, finest, yapese, gaseous,
# Nearest to time: period, night, day, noise, way, xxiv, disavowed, wickedness,
# Average loss at step 42000: 3.433083
# Average loss at step 44000: 3.456217
# Average loss at step 46000: 3.449013
# Average loss at step 48000: 3.356938
# Average loss at step 50000: 3.386132
# Nearest to or: and, than, forma, excelling, progressivism, handedness, any, but,
# Nearest to as: ching, collar, rothbard, resilient, formerly, supper, after, became,
# Nearest to these: some, many, those, several, both, such, mahindra, they,
# Nearest to four: six, five, three, seven, eight, nine, two, zero,
# Nearest to all: those, both, thinner, entrant, presides, these, interfered, some,
# Nearest to two: three, six, four, one, five, seven, eight, zero,
# Nearest to often: sometimes, usually, generally, commonly, also, frequently, widely, now,
# Nearest to used: known, referred, written, regarded, defined, found, described, available,
# Nearest to called: sill, repairing, spheroidal, varicella, seaton, ramp, dimensionless, schumann,
# Nearest to i: we, ii, you, g, they, t, transnational, robotech,
# Nearest to zero: five, four, seven, eight, six, nine, three, two,
# Nearest to no: any, little, nicea, strong, than, gir, bogside, motherhood,
# Nearest to into: handball, from, through, under, across, datatype, overtaken, byrd,
# Nearest to they: we, he, there, you, she, it, who, i,
# Nearest to at: during, wrecking, on, homo, amended, manicheanism, rie, multimedia,
# Nearest to time: period, night, way, day, year, disavowed, reason, xxiv,
# Average loss at step 52000: 3.434099
# Average loss at step 54000: 3.429050
# Average loss at step 56000: 3.437721
# Average loss at step 58000: 3.395356
# Average loss at step 60000: 3.395346
# Nearest to or: and, than, seine, any, handedness, like, forma, mages,
# Nearest to as: rothbard, zimbabwean, drayton, floral, ching, ribbons, using, interoperability,
# Nearest to these: some, many, those, such, both, several, all, which,
# Nearest to four: five, six, three, eight, seven, nine, two, zero,
# Nearest to all: those, some, many, these, any, various, thinner, both,
# Nearest to two: three, four, one, five, six, eight, seven, zero,
# Nearest to often: sometimes, usually, commonly, generally, frequently, still, also, now,
# Nearest to used: known, referred, described, regarded, written, defined, seen, published,
# Nearest to called: sill, used, formed, seaton, richmond, named, schumann, varicella,
# Nearest to i: we, ii, you, g, they, t, transnational, ritter,
# Nearest to zero: five, eight, four, seven, six, nine, three, two,
# Nearest to no: any, little, a, wolff, motherhood, gir, tter, notorious,
# Nearest to into: through, from, handball, across, under, towards, further, datatype,
# Nearest to they: we, there, you, he, she, i, these, it,
# Nearest to at: within, during, in, prefaces, rie, wrecking, michelin, zonker,
# Nearest to time: period, way, reason, night, year, day, evo, xxiv,
# Average loss at step 62000: 3.240087
# Average loss at step 64000: 3.254144
# Average loss at step 66000: 3.405731
# Average loss at step 68000: 3.396014
# Average loss at step 70000: 3.359264
# Nearest to or: and, than, any, your, thicknesses, like, wherein, pantheistic,
# Nearest to as: ching, drayton, like, zimbabwean, payne, peirce, rothbard, guadalupe,
# Nearest to these: many, such, some, those, several, various, the, mahindra,
# Nearest to four: six, five, three, seven, eight, two, nine, zero,
# Nearest to all: many, some, those, various, thinner, every, any, both,
# Nearest to two: three, four, one, six, seven, five, eight, zero,
# Nearest to often: sometimes, usually, commonly, generally, frequently, now, still, typically,
# Nearest to used: known, referred, found, regarded, written, described, responsible, available,
# Nearest to called: sill, considered, named, used, seaton, fetus, nutation, word,
# Nearest to i: we, ii, you, g, adsorption, ritter, szasz, t,
# Nearest to zero: five, eight, six, four, seven, nine, two, three,
# Nearest to no: little, any, strong, significant, tter, motherhood, nicea, ccf,
# Nearest to into: through, from, handball, across, further, under, stances, claremont,
# Nearest to they: we, there, he, she, you, it, indeed, earnhardt,
# Nearest to at: within, during, disruptions, in, finest, on, masterpieces, kach,
# Nearest to time: period, night, reason, way, evo, year, if, day,
# Average loss at step 72000: 3.371603
# Average loss at step 74000: 3.345901
# Average loss at step 76000: 3.312597
# Average loss at step 78000: 3.352408
# Average loss at step 80000: 3.379134
# Nearest to or: and, while, than, shema, thicknesses, but, sailplane, though,
# Nearest to as: ching, rothbard, tireless, ribbons, unheated, resilient, like, payne,
# Nearest to these: many, those, several, various, some, such, both, mahindra,
# Nearest to four: six, five, seven, three, eight, nine, two, zero,
# Nearest to all: both, every, various, many, thinner, any, some, those,
# Nearest to two: three, six, four, one, five, seven, eight, zero,
# Nearest to often: sometimes, usually, commonly, generally, frequently, typically, still, widely,
# Nearest to used: known, referred, written, seen, defined, designed, available, considered,
# Nearest to called: considered, referred, named, known, used, schumann, invert, innsbruck,
# Nearest to i: we, you, ii, g, t, iii, they, seq,
# Nearest to zero: seven, five, six, eight, four, three, nine, two,
# Nearest to no: little, any, strong, tter, nicea, desolation, bogside, cline,
# Nearest to into: through, from, handball, across, under, towards, during, over,
# Nearest to they: we, he, there, you, she, it, who, these,
# Nearest to at: in, within, disruptions, disliked, finest, during, around, dignified,
# Nearest to time: period, night, year, disavowed, day, reason, woolfson, vigilante,
# Average loss at step 82000: 3.410211
# Average loss at step 84000: 3.409591
# Average loss at step 86000: 3.393950
# Average loss at step 88000: 3.357330
# Average loss at step 90000: 3.367945
# Nearest to or: and, but, than, thicknesses, while, forma, though, pantheistic,
# Nearest to as: rothbard, exceptionally, ching, strikers, formerly, wcl, lemy, lameness,
# Nearest to these: many, several, some, those, various, are, mahindra, such,
# Nearest to four: five, seven, six, three, eight, two, nine, zero,
# Nearest to all: both, many, various, every, some, several, these, thinner,
# Nearest to two: three, six, four, five, seven, eight, one, zero,
# Nearest to often: sometimes, usually, commonly, frequently, generally, typically, still, widely,
# Nearest to used: referred, known, seen, employed, designed, described, able, defined,
# Nearest to called: named, considered, used, referred, schumann, blythe, desi, predominant,
# Nearest to i: we, you, g, ii, t, iii, iv, v,
# Nearest to zero: five, seven, six, eight, four, nine, three, two,
# Nearest to no: little, any, tsuka, tter, another, compared, narrowest, confronted,
# Nearest to into: through, from, handball, across, under, byrd, zquez, further,
# Nearest to they: we, he, there, she, it, you, these, indeed,
# Nearest to at: in, during, within, on, finest, rie, saumur, near,
# Nearest to time: period, night, reason, disavowed, day, salieri, if, copy,
# Average loss at step 92000: 3.397766
# Average loss at step 94000: 3.252033
# Average loss at step 96000: 3.356304
# Average loss at step 98000: 3.250913
# Average loss at step 100000: 3.356347
# Nearest to or: and, than, shema, selfless, handedness, bizkit, sailplane, utr,
# Nearest to as: vim, ching, lameness, ifrcs, drayton, unheated, hindrance, like,
# Nearest to these: many, several, those, some, various, all, were, different,
# Nearest to four: seven, six, five, eight, three, nine, two, zero,
# Nearest to all: every, various, both, these, any, several, many, those,
# Nearest to two: three, five, four, six, seven, one, eight, zero,
# Nearest to often: sometimes, usually, generally, commonly, frequently, typically, widely, still,
# Nearest to used: referred, designed, seen, defined, known, considered, written, available,
# Nearest to called: named, referred, used, desi, considered, innsbruck, see, blythe,
# Nearest to i: we, you, ii, they, tetrahedron, v, g, t,
# Nearest to zero: five, six, eight, four, seven, nine, two, three,
# Nearest to no: any, little, tter, diagnoses, nicea, azali, bogside, another,
# Nearest to into: through, from, across, within, handball, reginald, under, further,
# Nearest to they: we, he, there, you, she, it, i, earnhardt,
# Nearest to at: within, in, on, during, near, finest, after, trna,
# Nearest to time: night, period, disavowed, reason, way, year, day, copy,

# %%
final_embeddings.shape
# Out:
# (50000, 128)

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(18,18))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# --------
#
# # Problem
# An alternative to skip-gram is another Word2Vec model called CBOW (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.

# %% [markdown]
# For the continuous bag of words, the train inputs are slightly different from the skip-gram:

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1 # [ bag_window target bag_window ]
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        # just for testing
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        # iterate to the next buffer
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))  
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
labels
# Out:
# array([[ 12],
#        [  6],
#        [195],
#        [  2]], dtype=int32)

# %% [markdown]
# ----
# Note the instruction change on the loss function, with reduce_sum to sum the word vectors in the context:

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

# %%
with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                                                      stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    print(softmax_weights.dtype)
    print(softmax_biases.dtype)
    print(embeds.dtype)
    print(train_labels.dtype)
    
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embeds, 1),
                                                     labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# <dtype: 'float32_ref'>
# <dtype: 'float32_ref'>
# <dtype: 'float32'>
# <dtype: 'int32'>

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, bag_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 9.548376
# Nearest to be: mactutor, activated, megali, dischord, lancelot, amarna, christiania, wien,
# Nearest to had: frederick, devolved, paulus, aberrant, cumann, bay, drives, repertoire,
# Nearest to also: priest, koh, feral, manifests, oscillates, lifetime, orders, corps,
# Nearest to four: blitter, mandelbrot, aqueducts, works, rash, restraining, californian, separately,
# Nearest to as: marceau, dribble, viva, renamo, friar, canvas, plekhanov, lisboa,
# Nearest to united: heliocentric, carelessness, nicks, reinterpreted, vintage, montag, kitchens, pravda,
# Nearest to been: rhodesian, thelema, disadvantages, hoped, atonality, fractions, reprising, ape,
# Nearest to he: refractive, mccain, limbo, courtney, bogota, purchases, forecast, como,
# Nearest to see: inadvertently, satirizing, pli, unveiled, papeete, notations, sequencers, seaton,
# Nearest to a: schmitt, laodicea, toonami, wikiquote, loud, four, foxe, conquers,
# Nearest to one: veganism, consonantal, neill, bicycles, loewe, scepticism, adverts, cameroons,
# Nearest to was: taxpayer, dancers, claudius, epstein, marksmanship, darwinism, codifying, decedent,
# Nearest to many: snegur, jettisoned, comerica, schott, dispensing, wyoming, approaching, maintainers,
# Nearest to system: upbringing, zs, anode, ramgoolam, eager, tackles, zx, carbonates,
# Nearest to while: centrepiece, ed, uighur, appel, worcestershire, dk, wardrobe, alicante,
# Nearest to th: questionnaire, drawing, philosophiae, exaltation, resurrecting, stun, estonians, otc,
# Average loss at step 2000: 4.670452
# Average loss at step 4000: 3.884847
# Average loss at step 6000: 3.753802
# Average loss at step 8000: 3.450809
# Average loss at step 10000: 3.572922
# Nearest to be: being, refer, have, were, been, ergonomics, go, become,
# Nearest to had: has, have, was, were, having, pleases, distrito, platonism,
# Nearest to also: which, congolese, tune, still, warts, mayfield, tarnished, neill,
# Nearest to four: five, three, eight, six, seven, two, nine, zero,
# Nearest to as: disclaimed, tennant, majdanek, busing, turbo, acclaim, installment, doublespeak,
# Nearest to united: netherlands, fountainhead, heliocentric, causal, decentralization, vintage, doomed, grounding,
# Nearest to been: become, transitional, be, pebble, marmalade, tba, stat, was,
# Nearest to he: it, they, she, who, outcome, symmetrical, towns, count,
# Nearest to see: hydrophilic, intuitionism, hid, ballarat, competences, grandiose, telekom, steyr,
# Nearest to a: any, no, this, the, paullus, an, another, fokker,
# Nearest to one: seven, five, eight, three, six, four, nine, nottingham,
# Nearest to was: is, were, had, are, has, marksmanship, became, tyson,
# Nearest to many: some, several, most, other, all, these, those, carcass,
# Nearest to system: ramgoolam, upbringing, enoch, eager, star, craig, fairies, tautologies,
# Nearest to while: promiscuous, frankfurter, umlauts, empirically, manhood, until, janusz, malpighi,
# Nearest to th: sideways, weeping, nd, extractor, pacing, lyotropic, refinements, wiccan,
# Average loss at step 12000: 3.447348
# Average loss at step 14000: 3.471303
# Average loss at step 16000: 3.434346
# Average loss at step 18000: 3.272793
# Average loss at step 20000: 3.377168
# Nearest to be: refer, being, have, are, were, go, cause, distinguish,
# Nearest to had: has, have, having, endometrium, was, recompense, clinging, were,
# Nearest to also: often, still, reith, which, now, visas, malt, what,
# Nearest to four: five, six, eight, three, two, seven, zero, nine,
# Nearest to as: calf, multiplan, jute, felonies, discernment, disclaimed, avc, donatello,
# Nearest to united: netherlands, ashikaga, grounding, heliocentric, leaflet, frankish, authentically, worked,
# Nearest to been: become, come, forster, microfluidics, illuminatus, marmalade, byrds, shack,
# Nearest to he: she, it, who, they, count, turpentine, scorched, einstein,
# Nearest to see: hydrophilic, voltaire, ballarat, intuitionism, telekom, unpredictability, kid, processor,
# Nearest to a: the, an, any, another, this, chissano, his, every,
# Nearest to one: two, four, five, aphrodite, ranking, print, hsuan, orange,
# Nearest to was: is, became, were, are, wilcox, had, halfdan, has,
# Nearest to many: some, several, these, all, various, both, neuralgia, those,
# Nearest to system: systems, strive, crossover, noxious, case, star, network, del,
# Nearest to while: and, with, when, cheered, among, however, ed, pleasures,
# Nearest to th: st, nd, sixth, lyotropic, consubstantiation, upheaval, weeping, refinements,
# Average loss at step 22000: 3.350314
# Average loss at step 24000: 3.269319
# Average loss at step 26000: 3.268028
# Average loss at step 28000: 3.256309
# Average loss at step 30000: 3.205409
# Nearest to be: lead, refer, being, become, make, were, been, produce,
# Nearest to had: has, have, having, endometrium, was, includes, could, gave,
# Nearest to also: still, reith, often, neill, malt, now, effected, below,
# Nearest to four: seven, five, eight, six, three, nine, zero, two,
# Nearest to as: propeller, kreutzmann, tensor, nautilus, kritik, preparing, supplied, too,
# Nearest to united: leaflet, ashikaga, netherlands, other, frankish, authentically, fountainhead, prologue,
# Nearest to been: become, come, lineal, habeas, be, meantone, forster, marmalade,
# Nearest to he: she, it, they, who, already, copland, turpentine, terracotta,
# Nearest to see: ballarat, unpredictability, hydrophilic, called, but, rockingham, intuitionism, octaves,
# Nearest to a: another, any, the, no, anteater, ite, arbuckle, jugnauth,
# Nearest to one: two, seven, eight, nine, six, five, aphrodite, xxviii,
# Nearest to was: is, became, were, are, has, had, makes, halfdan,
# Nearest to many: some, several, various, all, most, carcass, reservation, different,
# Nearest to system: systems, program, strive, style, network, crossover, uke, emitters,
# Nearest to while: when, among, and, including, after, before, although, however,
# Nearest to th: nine, st, lyotropic, nd, tuners, unarable, exceptions, twentieth,
# Average loss at step 32000: 3.074658
# Average loss at step 34000: 3.190786
# Average loss at step 36000: 3.185282
# Average loss at step 38000: 3.174516
# Average loss at step 40000: 3.180060
# Nearest to be: refer, lead, being, become, produce, vary, remain, distinguish,
# Nearest to had: has, have, having, was, were, wrote, saw, ostensible,
# Nearest to also: still, now, never, zubaydah, often, reith, below, congolese,
# Nearest to four: seven, six, five, three, eight, zero, nine, two,
# Nearest to as: orgy, quays, fullwidth, tensor, became, among, constricted, lotta,
# Nearest to united: frankish, authentically, prologue, netherlands, teborg, ashikaga, hydrographic, fighters,
# Nearest to been: become, come, appeared, be, occurred, bartholomew, suffered, forster,
# Nearest to he: she, it, they, turpentine, timepieces, soc, disabled, blatant,
# Nearest to see: includes, intuitionism, called, ballarat, known, telekom, nocturnal, morphological,
# Nearest to a: another, the, any, reductions, every, fenway, each, this,
# Nearest to one: tents, plotinus, two, cet, monolith, agade, ka, expel,
# Nearest to was: is, were, became, has, are, becomes, being, remains,
# Nearest to many: some, several, various, all, neuralgia, these, most, those,
# Nearest to system: systems, strive, program, ods, crossover, citing, reduplication, cruise,
# Nearest to while: although, among, however, unlike, but, though, than, when,
# Nearest to th: st, nd, twentieth, lyotropic, sixteenth, nine, rd, inconsistently,
# Average loss at step 42000: 3.187509
# Average loss at step 44000: 3.135715
# Average loss at step 46000: 3.104872
# Average loss at step 48000: 3.070294
# Average loss at step 50000: 3.101621
# Nearest to be: refer, being, mean, lead, produce, remain, vary, twayne,
# Nearest to had: has, have, having, was, recherche, includes, saw, were,
# Nearest to also: actually, now, disambiguation, below, still, often, never, sometimes,
# Nearest to four: three, six, seven, five, eight, n, exalted, binet,
# Nearest to as: multiplan, robbins, meridian, juno, lessen, materiality, avc, audi,
# Nearest to united: frankish, radek, childbirth, inwo, leaflet, authentically, slots, urgent,
# Nearest to been: become, come, appeared, occurred, microfluidics, several, intro, pvp,
# Nearest to he: she, it, they, turpentine, already, modality, soc, there,
# Nearest to see: includes, known, intuitionism, nocturnal, voltaire, identities, def, theotokos,
# Nearest to a: the, another, any, no, every, each, this, an,
# Nearest to one: two, seven, three, aridity, four, est, nagarjuna, nine,
# Nearest to was: is, were, became, are, becomes, had, remains, makes,
# Nearest to many: some, several, various, certain, neuralgia, numerous, most, these,
# Nearest to system: systems, boric, midline, mailed, citing, rejoice, reduplication, process,
# Nearest to while: although, however, and, when, though, but, among, including,
# Nearest to th: nd, rd, lyotropic, twentieth, sixteenth, radioactive, refinements, weeping,
# Average loss at step 52000: 3.066654
# Average loss at step 54000: 3.091756
# Average loss at step 56000: 2.938992
# Average loss at step 58000: 3.039835
# Average loss at step 60000: 3.040939
# Nearest to be: lead, refer, provide, produce, take, get, remain, being,
# Nearest to had: has, have, having, was, were, contains, holds, could,
# Nearest to also: often, below, now, never, still, frequently, sometimes, actually,
# Nearest to four: three, six, five, seven, eight, zero, two, nine,
# Nearest to as: tensor, milos, spartans, familias, donatello, powerhouse, withstand, multiplan,
# Nearest to united: frankish, member, radek, zerby, prologue, stomping, netherlands, teborg,
# Nearest to been: become, come, occurred, replicators, remained, microfluidics, appeared, bartholomew,
# Nearest to he: she, it, already, they, who, turpentine, company, subsequently,
# Nearest to see: includes, voltaire, but, intuitionism, known, provides, tell, ballarat,
# Nearest to a: another, any, the, no, every, anteater, each, an,
# Nearest to one: two, transitioned, print, six, three, dispersing, migrating, necker,
# Nearest to was: is, were, remains, became, had, gave, are, has,
# Nearest to many: some, several, various, all, numerous, those, most, these,
# Nearest to system: systems, process, hub, traveller, practice, mailed, change, company,
# Nearest to while: although, though, when, among, and, however, because, but,
# Nearest to th: twentieth, nd, st, nine, nineteenth, exceptions, third, rd,
# Average loss at step 62000: 2.980172
# Average loss at step 64000: 2.960070
# Average loss at step 66000: 2.910330
# Average loss at step 68000: 2.979199
# Average loss at step 70000: 2.997410
# Nearest to be: lead, being, refer, become, mean, occur, produce, provide,
# Nearest to had: has, have, having, was, is, were, contains, wrote,
# Nearest to also: still, below, now, often, which, frequently, usually, currently,
# Nearest to four: five, six, seven, three, eight, two, zero, ish,
# Nearest to as: mintz, multiplan, meridian, installment, when, quays, donatello, millar,
# Nearest to united: frankish, member, confederate, nhadau, u, radek, zerby, stomping,
# Nearest to been: become, be, come, occurred, intro, remained, appeared, flavors,
# Nearest to he: she, it, they, turpentine, who, officially, arbuckle, dinoflagellates,
# Nearest to see: includes, known, provides, voltaire, octaves, tell, telekom, nocturnal,
# Nearest to a: the, another, every, any, jugnauth, ite, oliphant, no,
# Nearest to one: two, oop, chloroform, homeostasis, parlance, illuminati, eduke, surveys,
# Nearest to was: is, were, became, becomes, had, are, remains, does,
# Nearest to many: some, several, various, numerous, all, certain, modern, most,
# Nearest to system: systems, midline, banners, network, mailed, process, boric, reduplication,
# Nearest to while: however, although, when, and, though, among, but, because,
# Nearest to th: twentieth, nd, st, nineteenth, exceptions, nine, rd, cosmological,
# Average loss at step 72000: 2.831959
# Average loss at step 74000: 2.984280
# Average loss at step 76000: 3.010224
# Average loss at step 78000: 2.950124
# Average loss at step 80000: 2.864680
# Nearest to be: being, refer, lead, produce, provide, remain, occur, become,
# Nearest to had: has, have, having, wrote, was, gives, contains, provides,
# Nearest to also: below, currently, never, often, which, frequently, generally, already,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to as: multiplan, ifbb, like, russcol, dou, donatello, mintz, citt,
# Nearest to united: frankish, zerby, confederate, radek, renarrative, geographer, necromancers, tragically,
# Nearest to been: become, come, occurred, be, suffered, remained, grown, forster,
# Nearest to he: she, it, they, turpentine, previously, there, cortez, vested,
# Nearest to see: includes, provides, rilke, known, called, ballarat, assume, tell,
# Nearest to a: another, the, any, every, jugnauth, oliphant, wastewater, vertebra,
# Nearest to one: two, jogaila, parlance, six, print, icct, cet, corvus,
# Nearest to was: is, became, becomes, were, had, are, has, remains,
# Nearest to many: some, several, various, all, numerous, both, certain, thousands,
# Nearest to system: systems, process, sep, program, reduplication, midline, skill, topography,
# Nearest to while: when, although, where, and, though, among, towards, babbitt,
# Nearest to th: st, nd, twentieth, nineteenth, rd, nine, seventeenth, fourth,
# Average loss at step 82000: 2.935141
# Average loss at step 84000: 2.916287
# Average loss at step 86000: 2.933516
# Average loss at step 88000: 2.867010
# Average loss at step 90000: 2.874952
# Nearest to be: being, occur, lead, refer, been, represent, become, remain,
# Nearest to had: has, have, having, was, offers, wrote, could, contains,
# Nearest to also: below, still, often, now, which, disambiguation, currently, where,
# Nearest to four: six, seven, five, three, eight, zero, two, one,
# Nearest to as: citt, scat, donatello, thespis, installment, russcol, anorexia, depp,
# Nearest to united: frankish, sulfur, zerby, other, cooks, us, confederate, adjacent,
# Nearest to been: become, come, be, occurred, microfluidics, evolved, already, grown,
# Nearest to he: she, it, they, turpentine, poorly, asphyxiation, delirium, laguardia,
# Nearest to see: includes, provides, called, tell, add, telekom, contains, but,
# Nearest to a: another, any, the, every, this, oliphant, jugnauth, vertebra,
# Nearest to one: four, seven, icct, lomax, xxviii, two, parlance, eight,
# Nearest to was: is, were, became, are, becomes, remains, had, has,
# Nearest to many: some, several, various, numerous, all, most, both, fremantle,
# Nearest to system: systems, midline, process, sep, reduplication, network, principle, topography,
# Nearest to while: though, although, when, and, including, dumont, or, unlike,
# Nearest to th: nineteenth, twentieth, st, nd, seventeenth, fifteenth, next, eight,
# Average loss at step 92000: 2.901660
# Average loss at step 94000: 2.874042
# Average loss at step 96000: 2.443796
# Average loss at step 98000: 2.585549
# Average loss at step 100000: 2.814653
# Nearest to be: refer, being, occur, remain, have, produce, become, mean,
# Nearest to had: has, have, having, was, wrote, could, contains, holds,
# Nearest to also: below, now, actually, currently, already, frequently, disambiguation, nevertheless,
# Nearest to four: three, five, six, seven, eight, two, zero, nine,
# Nearest to as: installment, citt, donatello, disclaimed, goblins, jute, multiplan, custis,
# Nearest to united: confederate, frankish, member, us, slots, nhadau, other, sulfur,
# Nearest to been: become, come, occurred, gone, grown, fallen, previously, already,
# Nearest to he: she, it, they, injures, hannibal, turpentine, hitler, adret,
# Nearest to see: tell, includes, references, include, consider, refer, gives, add,
# Nearest to a: another, the, any, every, jugnauth, this, wastewater, his,
# Nearest to one: icct, parlance, poetics, cleve, two, maximization, conjunction, membered,
# Nearest to was: is, were, became, had, remains, halfdan, becomes, has,
# Nearest to many: some, several, various, numerous, both, all, those, hundreds,
# Nearest to system: systems, process, midline, method, network, topography, traveller, code,
# Nearest to while: when, although, though, before, however, and, where, murphy,
# Nearest to th: twentieth, nineteenth, nd, st, rd, fourth, seventeenth, seventh,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# Some clusters are less obvious (like the standalone characters), but it clearly totaly works!
# How does your CBOW model perform compared to the given Word2Vec model? (to be answered)
# At the first sight, they look similar. The CBOW is a more compact.
