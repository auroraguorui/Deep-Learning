# %% [markdown]
# # Deep Learning
# ### Assignment 5
# The goal of this assignment is to train a Word2Vec skip-gram model over Text8 data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
        unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 17005207], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

# %%
print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'of', 'originated', 'as', 'term']

# %% [markdown]
# ----
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

# %%
with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                                                      stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                                                     train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.274455
# Nearest to all: infamy, regolith, barnum, rameses, towering, iau, bridges, repetitive,
# Nearest to if: unexpectedly, admiring, global, houghton, limbic, rivaling, balaenoptera, bunny,
# Nearest to about: ecclesiastics, aslan, expressive, highgate, chechen, sociological, tuesday, aero,
# Nearest to are: oas, vanquished, affirming, fletcher, normalized, meru, upwards, elementary,
# Nearest to that: salad, americans, learners, bouvines, kenilworth, magie, kiang, dialing,
# Nearest to states: overseer, wanderers, acclaimed, anecdote, internetworking, midlands, uproar, ravel,
# Nearest to to: varese, ligamentum, stretch, def, adaption, multiplying, appreciable, severus,
# Nearest to d: dragons, nepotism, funimation, purporting, adrian, fubar, earned, physicalism,
# Nearest to was: pizarro, nebraska, ha, goalkeeper, wow, strident, adages, oval,
# Nearest to may: conviction, argentinean, nicosia, derivates, jacob, surrealism, backpack, oddie,
# Nearest to two: braveheart, overlooking, theater, unger, kingfisher, plantation, diligently, zeno,
# Nearest to he: plasticizers, dillon, lethargy, sieges, forgotten, rambling, licks, civil,
# Nearest to with: pull, quantity, apprenticeship, judging, lucretia, exposed, physiologic, speculates,
# Nearest to they: rhymes, poincar, aberystwyth, instructing, pollinator, roz, sidearm, aj,
# Nearest to only: gleaming, incoming, omri, potential, annul, newline, benoit, crustacean,
# Nearest to who: weakens, perfective, physica, reflection, recognizing, encephalopathy, submissive, castello,
# Average loss at step 2000: 4.365573
# Average loss at step 4000: 3.858789
# Average loss at step 6000: 3.787429
# Average loss at step 8000: 3.687322
# Average loss at step 10000: 3.611683
# Nearest to all: centuries, rameses, barnum, symbionts, cities, cbs, regolith, bombardment,
# Nearest to if: when, oakenfold, racist, unexpectedly, global, orient, admiring, cyclopaedia,
# Nearest to about: aslan, highgate, further, expressive, sociological, ecclesiastics, chechen, tuesday,
# Nearest to are: were, is, have, thrilling, vanquished, pasted, was, gry,
# Nearest to that: which, what, bouvines, it, vocalized, cared, varanus, montt,
# Nearest to states: wanderers, overseer, forcing, manifestos, disestablished, reacting, hillery, midlands,
# Nearest to to: not, would, severus, def, torpedoes, appreciable, stretch, ankle,
# Nearest to d: and, nepotism, purporting, b, cancelling, fubar, dragons, rubin,
# Nearest to was: is, had, were, by, has, be, points, became,
# Nearest to may: will, can, could, would, derivates, dent, binder, inspector,
# Nearest to two: five, three, four, six, eight, nine, seven, one,
# Nearest to he: it, she, they, who, liqueur, dillon, there, requires,
# Nearest to with: in, for, when, install, inability, cheated, after, distortion,
# Nearest to they: he, it, not, courtroom, poincar, booty, slack, primarily,
# Nearest to only: incoming, turk, packet, yitzchak, nacht, waltham, obscures, cafe,
# Nearest to who: he, and, weakens, which, we, also, deco, fubar,
# Average loss at step 12000: 3.604322
# Average loss at step 14000: 3.565486
# Average loss at step 16000: 3.409070
# Average loss at step 18000: 3.459530
# Average loss at step 20000: 3.539881
# Nearest to all: these, many, some, rameses, several, bridges, various, symbionts,
# Nearest to if: when, took, though, flatter, whitacre, racist, unexpectedly, but,
# Nearest to about: copeland, aslan, gee, boron, exert, chechen, sociological, highgate,
# Nearest to are: were, is, have, was, thrilling, be, other, pasted,
# Nearest to that: which, what, but, however, srivijaya, bouvines, vocalized, this,
# Nearest to states: disestablished, wanderers, overseer, internetworking, forcing, globalization, marina, selma,
# Nearest to to: would, not, meade, must, severus, can, stretch, will,
# Nearest to d: b, swedish, purporting, referendum, felony, rubin, fiefs, dragons,
# Nearest to was: is, were, had, has, be, became, are, when,
# Nearest to may: can, would, will, could, should, must, might, ale,
# Nearest to two: three, four, five, six, one, seven, eight, nine,
# Nearest to he: it, they, she, who, there, passos, never, liqueur,
# Nearest to with: in, or, for, between, from, when, by, after,
# Nearest to they: he, we, there, it, then, not, she, courtroom,
# Nearest to only: nacht, turk, newline, incoming, packet, normally, ade, obscures,
# Nearest to who: he, which, originally, also, they, often, it, deco,
# Average loss at step 22000: 3.499780
# Average loss at step 24000: 3.488174
# Average loss at step 26000: 3.479602
# Average loss at step 28000: 3.480032
# Average loss at step 30000: 3.500792
# Nearest to all: some, these, many, various, several, those, rameses, both,
# Nearest to if: when, though, turkish, whitacre, flatter, racist, is, reissues,
# Nearest to about: further, boron, maasai, on, underdeveloped, rolle, sociological, regarding,
# Nearest to are: were, is, have, these, those, other, pasted, thrilling,
# Nearest to that: which, what, however, this, lcd, bouvines, but, lyra,
# Nearest to states: disestablished, nations, internetworking, overseer, wanderers, compilation, globalization, nervous,
# Nearest to to: would, can, severus, must, appreciable, will, tendons, not,
# Nearest to d: b, referendum, swedish, sprengel, rubin, felony, fiefs, woody,
# Nearest to was: is, had, has, were, been, became, when, niggers,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Nearest to two: four, three, five, seven, six, eight, one, nine,
# Nearest to he: it, she, they, who, there, never, passos, liqueur,
# Nearest to with: between, when, pacification, by, in, from, against, shells,
# Nearest to they: we, there, he, it, not, you, who, these,
# Nearest to only: newline, incoming, dropouts, nacht, normally, not, drawings, cafe,
# Nearest to who: he, which, they, and, originally, also, she, it,
# Average loss at step 32000: 3.497865
# Average loss at step 34000: 3.494755
# Average loss at step 36000: 3.454721
# Average loss at step 38000: 3.294649
# Average loss at step 40000: 3.428476
# Nearest to all: both, these, ishiro, various, several, many, jurists, some,
# Nearest to if: when, where, turkish, though, is, whitacre, can, flatter,
# Nearest to about: further, regarding, boron, relieved, maasai, orr, hospitable, falconiformes,
# Nearest to are: were, have, is, including, these, those, include, pasted,
# Nearest to that: which, what, this, however, it, cosmogony, bouvines, southward,
# Nearest to states: nations, disestablished, internetworking, wanderers, kingdom, globalization, ovum, overseer,
# Nearest to to: must, can, tendons, in, will, would, mistakenly, from,
# Nearest to d: b, h, r, referendum, c, felony, girlfriends, masts,
# Nearest to was: is, became, were, has, been, had, be, when,
# Nearest to may: can, will, could, would, should, must, might, cannot,
# Nearest to two: three, five, four, six, one, seven, eight, nine,
# Nearest to he: she, it, they, who, there, i, passos, tunneling,
# Nearest to with: between, by, shells, inability, in, miscellany, from, cheated,
# Nearest to they: we, he, there, you, it, these, not, she,
# Nearest to only: normally, turk, modulated, drawings, newline, incoming, even, massage,
# Nearest to who: he, which, often, also, they, she, originally, buttocks,
# Average loss at step 42000: 3.430414
# Average loss at step 44000: 3.448855
# Average loss at step 46000: 3.452140
# Average loss at step 48000: 3.354218
# Average loss at step 50000: 3.379000
# Nearest to all: both, these, some, many, various, each, admit, every,
# Nearest to if: when, where, though, however, whitacre, can, before, although,
# Nearest to about: further, regarding, maasai, falconiformes, grossed, anarchic, boron, copeland,
# Nearest to are: were, is, have, those, be, daimler, being, mithraea,
# Nearest to that: which, however, what, vocalized, this, pretends, readily, because,
# Nearest to states: nations, kingdom, disestablished, selma, globalization, compilation, nervous, ovum,
# Nearest to to: would, could, can, might, tendons, should, severus, consecrate,
# Nearest to d: b, r, h, l, g, sprengel, c, reciprocity,
# Nearest to was: is, were, has, had, became, been, be, by,
# Nearest to may: can, would, could, will, should, must, might, cannot,
# Nearest to two: three, four, one, seven, six, eight, five, nine,
# Nearest to he: she, it, they, who, there, passos, this, eventually,
# Nearest to with: between, by, parole, distortion, against, selecting, allophones, pacification,
# Nearest to they: he, we, there, you, she, it, who, passos,
# Nearest to only: normally, newline, still, dropouts, drawings, currently, not, welling,
# Nearest to who: he, which, they, she, never, originally, often, there,
# Average loss at step 52000: 3.432981
# Average loss at step 54000: 3.424685
# Average loss at step 56000: 3.441173
# Average loss at step 58000: 3.398408
# Average loss at step 60000: 3.392499
# Nearest to all: both, those, these, many, various, some, regolith, each,
# Nearest to if: when, where, though, licklider, before, because, although, so,
# Nearest to about: regarding, boron, further, over, donohue, keno, maasai, disenfranchised,
# Nearest to are: were, is, have, these, pasted, including, those, other,
# Nearest to that: which, what, however, this, santorini, vocalized, boziz, cosmogony,
# Nearest to states: nations, kingdom, disestablished, globalization, compilation, selma, nervous, fretboard,
# Nearest to to: appreciable, not, would, varese, cramps, will, cayenne, must,
# Nearest to d: b, h, r, m, sprengel, l, c, girlfriends,
# Nearest to was: is, became, had, were, has, be, when, been,
# Nearest to may: can, would, could, will, should, must, might, cannot,
# Nearest to two: three, four, six, five, eight, one, seven, nine,
# Nearest to he: she, it, they, who, there, tardis, we, tunneling,
# Nearest to with: between, when, in, against, including, frigate, fleischer, cheated,
# Nearest to they: we, there, he, you, she, it, these, who,
# Nearest to only: normally, drawings, first, apeiron, still, currently, dionysus, newline,
# Nearest to who: he, now, never, often, which, they, originally, still,
# Average loss at step 62000: 3.239219
# Average loss at step 64000: 3.254581
# Average loss at step 66000: 3.397501
# Average loss at step 68000: 3.393876
# Average loss at step 70000: 3.360138
# Nearest to all: both, many, some, various, those, any, every, jurists,
# Nearest to if: when, though, where, although, because, is, before, licklider,
# Nearest to about: regarding, further, approximately, over, maasai, galla, overgrown, disenfranchised,
# Nearest to are: were, is, have, including, these, those, include, be,
# Nearest to that: which, however, what, vocalized, this, santorini, often, but,
# Nearest to states: nations, kingdom, disestablished, state, countries, globalization, compilation, overseer,
# Nearest to to: can, will, would, must, may, could, spectacularly, always,
# Nearest to d: b, h, r, l, k, elizabethan, suppresses, adrian,
# Nearest to was: is, were, has, had, became, been, when, being,
# Nearest to may: can, will, could, would, might, must, should, cannot,
# Nearest to two: three, six, four, five, seven, one, eight, nine,
# Nearest to he: she, it, they, there, passos, who, we, imply,
# Nearest to with: between, when, unjust, against, alomar, frigate, fleischer, selecting,
# Nearest to they: we, he, there, you, it, she, eventually, even,
# Nearest to only: normally, still, drawings, usually, not, first, heiden, best,
# Nearest to who: never, often, he, which, they, she, now, actually,
# Average loss at step 72000: 3.371031
# Average loss at step 74000: 3.349780
# Average loss at step 76000: 3.312382
# Average loss at step 78000: 3.346023
# Average loss at step 80000: 3.377984
# Nearest to all: both, many, any, various, every, those, some, each,
# Nearest to if: when, where, though, because, although, before, then, cannot,
# Nearest to about: regarding, approximately, manors, over, orkney, disenfranchised, wd, galla,
# Nearest to are: were, have, is, although, include, those, including, these,
# Nearest to that: however, which, santorini, bouvines, what, asexual, where, lambar,
# Nearest to states: nations, kingdom, disestablished, state, countries, globalization, compilation, internetworking,
# Nearest to to: should, must, coles, zeitgeist, cramps, tacit, tendons, pus,
# Nearest to d: b, h, m, l, elizabethan, c, f, te,
# Nearest to was: is, were, became, had, has, being, although, be,
# Nearest to may: can, will, would, could, must, should, might, cannot,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to he: she, it, they, there, who, passos, we, eventually,
# Nearest to with: between, when, in, into, involving, unjust, or, against,
# Nearest to they: we, he, there, you, she, it, these, not,
# Nearest to only: normally, still, first, last, usually, tied, exorbitant, modelled,
# Nearest to who: he, never, often, which, actually, she, usually, they,
# Average loss at step 82000: 3.407338
# Average loss at step 84000: 3.407783
# Average loss at step 86000: 3.388097
# Average loss at step 88000: 3.350170
# Average loss at step 90000: 3.364141
# Nearest to all: many, both, some, every, various, any, those, several,
# Nearest to if: when, where, though, although, is, licklider, since, because,
# Nearest to about: regarding, over, approximately, qing, anarchic, manors, galla, wasteland,
# Nearest to are: were, is, include, have, these, although, exist, stub,
# Nearest to that: however, which, but, lambar, generally, reproducible, vocalized, lcd,
# Nearest to states: nations, kingdom, disestablished, state, countries, globalization, us, compilation,
# Nearest to to: cramps, will, would, tacit, spectacularly, obiang, towards, monsanto,
# Nearest to d: h, b, elizabethan, initialism, middletown, susan, m, zero,
# Nearest to was: is, had, became, were, has, be, been, being,
# Nearest to may: can, could, would, will, must, should, might, cannot,
# Nearest to two: three, five, four, six, seven, eight, one, nine,
# Nearest to he: she, it, they, there, who, eventually, but, gnutella,
# Nearest to with: between, by, when, against, in, amongst, hipparcos, heifer,
# Nearest to they: we, he, there, you, she, it, eventually, these,
# Nearest to only: normally, even, apeiron, no, drawings, last, santorum, lets,
# Nearest to who: he, often, which, never, she, usually, also, hamburgers,
# Average loss at step 92000: 3.398587
# Average loss at step 94000: 3.251747
# Average loss at step 96000: 3.364364
# Average loss at step 98000: 3.245487
# Average loss at step 100000: 3.355469
# Nearest to all: many, various, both, every, any, these, some, several,
# Nearest to if: when, where, though, because, before, licklider, although, since,
# Nearest to about: regarding, magically, anarchic, on, approximately, over, manors, galla,
# Nearest to are: were, have, exist, those, is, although, be, mithraea,
# Nearest to that: which, however, what, santorini, vocalized, patan, who, reproducible,
# Nearest to states: nations, kingdom, disestablished, countries, us, state, globalization, workers,
# Nearest to to: will, could, can, should, must, coles, would, severus,
# Nearest to d: b, h, j, r, physicalism, c, elizabethan, cooks,
# Nearest to was: is, became, has, were, been, had, jacobins, being,
# Nearest to may: can, could, would, must, will, should, might, cannot,
# Nearest to two: five, four, six, three, seven, one, eight, nine,
# Nearest to he: she, it, they, there, we, who, never, passos,
# Nearest to with: between, including, when, alomar, plasticity, by, amongst, kbe,
# Nearest to they: we, he, there, you, she, it, these, i,
# Nearest to only: normally, still, no, apeiron, not, modelled, apoplexy, simplified,
# Nearest to who: he, never, often, which, usually, she, actually, still,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# --------
#
# # Problem
# An alternative to skip-gram is another Word2Vec model called CBOW (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.

# %% [markdown]
# For the continuous bag of words, the train inputs are slightly different from the skip-gram:

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1 # [ bag_window target bag_window ]
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        # just for testing
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        # iterate to the next buffer
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))  
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %% [markdown]
# ----
# Note the instruction change on the loss function, with reduce_sum to sum the word vectors in the context:

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

# %%
with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                                                      stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
                                                     train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, bag_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.836586
# Nearest to to: prairie, yerushalmi, dealers, montgomery, banishing, autocorrelation, marianas, animator,
# Nearest to six: colonial, embryology, ranger, rothbard, saguinus, gotten, validity, glare,
# Nearest to the: linebackers, wallach, wg, codeine, lyricist, oceans, kabbalistic, thank,
# Nearest to called: quench, outright, scribes, dictation, hatti, baylor, kindling, diacritical,
# Nearest to over: chamorro, inefficiencies, lynne, masoch, orbital, bulfinch, antlia, sociopathic,
# Nearest to new: obeying, fante, byu, lam, solute, scarlatti, nukem, geer,
# Nearest to one: avar, isomer, drusilla, belly, portman, christchurch, dumplings, lonnie,
# Nearest to only: abdominal, woodpeckers, prattica, hummingbird, intermediary, cases, brazilians, serra,
# Nearest to united: liar, laminar, middle, harvey, volk, wingers, ramadan, monica,
# Nearest to such: altay, marianne, saltpeter, bootlegged, elijah, namespaces, perdition, glagolitic,
# Nearest to would: complications, gyroscopic, sportspeople, homme, holders, prat, mintz, bowl,
# Nearest to most: romanus, iigs, lothar, pleated, smithsonian, mockumentary, penguin, foremost,
# Nearest to also: pickup, deepen, vainly, distressing, sith, guile, uw, adjudication,
# Nearest to by: waging, deter, martina, raid, sensitivities, beluga, obstruction, distortions,
# Nearest to a: trustworthy, tagged, hiroshi, approval, longship, blankets, roadie, evangelicals,
# Nearest to no: yacc, populous, myron, illicit, byelorussia, lascaux, afx, prospered,
# Average loss at step 2000: 4.994359
# Average loss at step 4000: 4.007984
# Average loss at step 6000: 3.769611
# Average loss at step 8000: 3.552247
# Average loss at step 10000: 3.504245
# Nearest to to: may, will, can, would, cannot, must, autocorrelation, should,
# Nearest to six: eight, four, five, nine, zero, seven, window, silver,
# Nearest to the: its, their, this, a, his, scooby, some, meg,
# Nearest to called: quench, luba, sef, used, neumann, casual, oral, struggles,
# Nearest to over: lito, throughout, scottsdale, essayist, migs, voluntary, nder, thinkpad,
# Nearest to new: subtracted, repeating, exceptional, lcds, londinium, zander, umayyad, polemical,
# Nearest to one: nostrand, gy, liszt, three, lehrer, eoin, nine, illustrating,
# Nearest to only: lemmon, aphelion, usual, sword, reluctance, blackboard, first, auteur,
# Nearest to united: middle, osorio, santer, deny, kimmel, cgpm, wg, pekka,
# Nearest to such: well, known, faction, far, dragoon, liz, hannity, pm,
# Nearest to would: can, will, may, should, must, could, cannot, to,
# Nearest to most: many, more, some, subnational, identification, ecosystems, gypsy, demographics,
# Nearest to also: which, often, matthew, gonzo, waldemar, quatre, restorer, maclaurin,
# Nearest to by: zarqawi, incas, timer, compose, libya, under, weir, fils,
# Nearest to a: an, any, no, another, the, this, elsinore, skirmishes,
# Nearest to no: a, beheld, populous, yacc, manuals, azhar, emphasised, fetching,
# Average loss at step 12000: 3.551788
# Average loss at step 14000: 3.480383
# Average loss at step 16000: 3.455405
# Average loss at step 18000: 3.430413
# Average loss at step 20000: 3.237096
# Nearest to to: will, could, must, may, would, should, can, against,
# Nearest to six: five, seven, four, eight, three, nine, zero, two,
# Nearest to the: a, their, its, his, any, nihilism, rats, an,
# Nearest to called: used, luba, quench, named, known, struggles, lastly, shrimp,
# Nearest to over: during, through, at, inclinations, kenobi, throughout, hadley, mp,
# Nearest to new: beaverbrook, repeating, ptolemaic, housekeeper, nukem, exceptional, magnon, complete,
# Nearest to one: heldenplatz, epicurean, tunings, occurring, opel, darmstadt, harding, fog,
# Nearest to only: anesthesia, auteur, necessarily, reworked, jinshi, egoism, detachment, cheers,
# Nearest to united: kimmel, middle, pekka, santer, cgpm, entirety, hippolyte, spite,
# Nearest to such: well, known, regarded, far, result, mime, seen, designated,
# Nearest to would: will, may, could, should, can, must, might, cannot,
# Nearest to most: more, identification, many, minorca, very, some, paranthropus, designation,
# Nearest to also: often, still, now, never, censored, below, uralic, matthew,
# Nearest to by: zarqawi, lir, ciconiiformes, pumpkin, streaming, sickness, with, fiendish,
# Nearest to a: the, another, any, marbury, an, roi, magnentius, tauris,
# Nearest to no: any, courant, huygens, forestall, escudo, despotic, maidstone, azhar,
# Average loss at step 22000: 3.366511
# Average loss at step 24000: 3.304983
# Average loss at step 26000: 3.275373
# Average loss at step 28000: 3.289587
# Average loss at step 30000: 3.240341
# Nearest to to: must, will, shall, would, should, may, might, eyre,
# Nearest to six: eight, nine, seven, five, four, three, zero, two,
# Nearest to the: their, a, its, his, our, contesting, anabaptism, cautionary,
# Nearest to called: used, considered, palmer, named, ablaze, sula, fusing, luba,
# Nearest to over: around, inclinations, through, about, before, folio, during, throughout,
# Nearest to new: ptolemaic, repeating, nukem, complete, petropavlovsk, via, pumping, squirt,
# Nearest to one: two, five, yassir, letterbox, andropov, dar, seven, dorne,
# Nearest to only: lenihan, last, currie, cramer, bypasses, unacceptably, contraceptives, crashing,
# Nearest to united: entirety, spite, middle, cgpm, santer, katydids, arbitrate, bogs,
# Nearest to such: well, regarded, far, result, known, fondness, described, seen,
# Nearest to would: could, will, should, may, can, must, might, does,
# Nearest to most: many, some, more, identification, best, eutelsat, russcol, minorca,
# Nearest to also: still, often, sometimes, now, usually, below, matthew, amour,
# Nearest to by: who, freyr, timer, capra, favors, solidify, stair, imperialist,
# Nearest to a: the, any, another, aquariums, peripheries, wreck, every, marbury,
# Nearest to no: any, nothing, never, confirmed, aum, seton, beheld, dig,
# Average loss at step 32000: 3.021662
# Average loss at step 34000: 3.222108
# Average loss at step 36000: 3.203198
# Average loss at step 38000: 3.176431
# Average loss at step 40000: 3.186905
# Nearest to to: must, will, cannot, may, can, should, would, pnv,
# Nearest to six: eight, five, seven, four, three, zero, nine, one,
# Nearest to the: a, its, any, their, this, an, his, leinster,
# Nearest to called: considered, named, used, undetectable, known, luba, considers, ministerio,
# Nearest to over: around, throughout, under, about, inclinations, reproducible, during, across,
# Nearest to new: nukem, alloying, pumping, dated, complete, petropavlovsk, rambla, gearing,
# Nearest to one: finely, four, six, plectrum, payloads, haphazard, rondo, offended,
# Nearest to only: generally, misogynist, usually, leslie, every, religiously, haworth, decision,
# Nearest to united: katydids, entirety, spite, pekka, heliopause, santer, disparaging, stephenson,
# Nearest to such: well, regarded, far, classified, follows, result, seen, just,
# Nearest to would: will, could, may, can, must, should, might, cannot,
# Nearest to most: many, some, less, more, minorca, best, layered, russcol,
# Nearest to also: still, now, below, never, usually, generally, actually, progressed,
# Nearest to by: when, stair, who, powell, rationalistic, with, among, capra,
# Nearest to a: any, another, every, the, an, masturbation, elsinore, this,
# Nearest to no: any, nothing, kroto, each, never, azhar, hellenistic, every,
# Average loss at step 42000: 3.222785
# Average loss at step 44000: 3.151026
# Average loss at step 46000: 3.153709
# Average loss at step 48000: 3.068161
# Average loss at step 50000: 3.063941
# Nearest to to: will, must, could, towards, cannot, can, should, would,
# Nearest to six: seven, five, four, three, eight, nine, zero, two,
# Nearest to the: its, his, a, their, an, errand, nihilism, this,
# Nearest to called: named, used, although, luba, abolitionist, considers, pranksters, known,
# Nearest to over: around, during, throughout, across, off, through, reproducible, into,
# Nearest to new: pumping, different, facial, intertwined, trist, rambla, nukem, canidae,
# Nearest to one: monoid, jeopardy, oi, addition, breakdancing, two, approaching, this,
# Nearest to only: bane, keiretsu, even, diesel, cdots, satyr, actually, misogynist,
# Nearest to united: pekka, spite, entirety, lurker, katydids, santer, heliopause, following,
# Nearest to such: well, seen, described, known, classified, designated, regarded, result,
# Nearest to would: could, will, should, may, must, might, can, did,
# Nearest to most: many, some, more, especially, less, best, all, minorca,
# Nearest to also: still, below, actually, now, often, usually, resonance, stint,
# Nearest to by: freyr, timer, zarqawi, among, with, stair, when, under,
# Nearest to a: another, any, the, roi, every, this, manometer, beatification,
# Nearest to no: any, nothing, little, dig, ignorance, never, pubescent, manuals,
# Average loss at step 52000: 3.113846
# Average loss at step 54000: 3.112544
# Average loss at step 56000: 2.929572
# Average loss at step 58000: 3.039130
# Average loss at step 60000: 3.051226
# Nearest to to: will, could, would, might, cannot, toward, must, should,
# Nearest to six: five, seven, eight, four, three, nine, zero, two,
# Nearest to the: their, its, his, a, another, this, an, our,
# Nearest to called: named, used, considered, held, referred, dubbed, described, persuades,
# Nearest to over: during, across, through, beyond, throughout, alanine, klamath, kenobi,
# Nearest to new: facial, laugh, specific, modern, squirt, rambla, different, ghibli,
# Nearest to one: addition, breakdancing, lampooned, mtu, participated, cartel, plantarum, montferrat,
# Nearest to only: actually, last, warmer, sagittarius, deliberations, already, no, durkheim,
# Nearest to united: spite, katydids, entirety, lurker, santer, pekka, bogs, heliopause,
# Nearest to such: well, known, follows, result, seen, described, regarded, just,
# Nearest to would: will, could, might, may, should, must, can, did,
# Nearest to most: more, some, many, particularly, extremely, all, less, especially,
# Nearest to also: actually, never, still, now, often, below, sometimes, generally,
# Nearest to by: thus, toward, through, favors, mohamed, from, under, prion,
# Nearest to a: another, any, every, the, no, peripheries, this, beatification,
# Nearest to no: any, nothing, little, neither, a, without, still, courant,
# Average loss at step 62000: 3.037511
# Average loss at step 64000: 2.928446
# Average loss at step 66000: 2.942362
# Average loss at step 68000: 2.972915
# Average loss at step 70000: 3.016845
# Nearest to to: will, must, could, cannot, would, can, should, may,
# Nearest to six: seven, five, three, eight, four, two, zero, mj,
# Nearest to the: its, their, a, his, bouts, our, thousands, elba,
# Nearest to called: named, considered, included, considers, used, known, referred, termed,
# Nearest to over: through, landlocked, across, about, under, klamath, kenobi, beyond,
# Nearest to new: specific, different, pumping, nukem, modern, squirt, repeating, ptolemaic,
# Nearest to one: dar, unveils, landowner, fainter, dolphins, invent, osiris, roald,
# Nearest to only: keyword, leetspeak, rica, actually, he, first, realisation, invariable,
# Nearest to united: spite, lurker, entirety, confederate, katydids, santer, pekka, khagan,
# Nearest to such: well, follows, classified, whole, described, known, seen, regarded,
# Nearest to would: will, could, should, might, must, can, may, did,
# Nearest to most: many, more, some, particularly, increasingly, insertions, very, snout,
# Nearest to also: below, now, never, often, still, actually, usually, disambiguation,
# Nearest to by: among, when, fiendish, through, footprints, who, timer, sisterhood,
# Nearest to a: another, the, any, every, this, no, beatification, an,
# Nearest to no: another, wedded, artiodactyla, a, nothing, rossby, any, escudo,
# Average loss at step 72000: 2.952911
# Average loss at step 74000: 2.874419
# Average loss at step 76000: 3.002142
# Average loss at step 78000: 3.013165
# Average loss at step 80000: 2.852363
# Nearest to to: might, will, could, toward, can, cannot, would, towards,
# Nearest to six: eight, seven, five, four, three, nine, zero, chromosome,
# Nearest to the: their, its, a, another, our, his, scooby, errand,
# Nearest to called: named, considered, considers, used, included, referred, joined, played,
# Nearest to over: around, kenobi, throughout, across, listing, nearly, during, reproducible,
# Nearest to new: different, nukem, intertwined, specific, pumping, squirt, ptolemaic, trist,
# Nearest to one: breakdancing, dar, loft, nostrand, intron, genevieve, spite, monoid,
# Nearest to only: always, already, actually, either, unfamiliar, blige, cdots, just,
# Nearest to united: katydids, spite, lurker, jehoahaz, duesberg, salmon, starred, baltic,
# Nearest to such: well, follows, seen, described, classified, opposed, serve, referred,
# Nearest to would: could, will, might, must, can, should, cannot, may,
# Nearest to most: less, more, many, first, extremely, worst, some, particularly,
# Nearest to also: never, sometimes, below, now, currently, often, actually, still,
# Nearest to by: toward, fang, zarqawi, rationalistic, fiendish, among, originally, lughnasadh,
# Nearest to a: another, any, the, every, marbury, an, no, repugnant,
# Nearest to no: any, nothing, neither, secant, little, another, never, wedded,
# Average loss at step 82000: 2.945276
# Average loss at step 84000: 2.897186
# Average loss at step 86000: 2.924808
# Average loss at step 88000: 2.949330
# Average loss at step 90000: 2.830851
# Nearest to to: might, will, cannot, must, towards, would, may, should,
# Nearest to six: four, three, eight, seven, five, nine, two, zero,
# Nearest to the: a, its, any, his, an, their, another, wrapping,
# Nearest to called: named, considered, used, termed, referred, known, included, dubbed,
# Nearest to over: around, across, within, beyond, throughout, about, kenobi, inclinations,
# Nearest to new: intertwined, nukem, modern, ptolemaic, previous, atta, trist, edinburgh,
# Nearest to one: four, nine, six, seven, two, oi, backspace, zero,
# Nearest to only: always, candlemas, last, keiretsu, avercamp, prepares, jagan, morrissey,
# Nearest to united: lurker, katydids, uk, duesberg, bogs, baltic, khagan, cumont,
# Nearest to such: well, follows, result, seen, known, classified, viewed, regarded,
# Nearest to would: will, could, might, may, should, can, must, cannot,
# Nearest to most: some, many, especially, more, less, particularly, worst, enosis,
# Nearest to also: currently, below, still, disambiguation, which, often, sometimes, traditionally,
# Nearest to by: through, when, without, zarqawi, capra, toward, fiendish, after,
# Nearest to a: another, any, the, every, this, sncf, marbury, an,
# Nearest to no: little, nothing, secant, any, never, neither, rossby, another,
# Average loss at step 92000: 2.901633
# Average loss at step 94000: 2.892562
# Average loss at step 96000: 2.717184
# Average loss at step 98000: 2.460833
# Average loss at step 100000: 2.711797
# Nearest to to: would, might, must, will, cannot, should, can, could,
# Nearest to six: five, seven, four, three, eight, nine, zero, two,
# Nearest to the: her, a, his, their, its, another, unintended, clarkson,
# Nearest to called: named, used, considered, considers, dubbed, referred, described, known,
# Nearest to over: throughout, through, across, about, around, beyond, kenobi, off,
# Nearest to new: nukem, modern, intertwined, ptolemaic, squirt, trist, pumping, laugh,
# Nearest to one: spite, microphone, novelties, dms, beauties, intercession, certify, liv,
# Nearest to only: always, first, longest, last, lobbied, latter, folkloric, q,
# Nearest to united: katydids, confederate, duesberg, baltic, lurker, brig, spite, cumont,
# Nearest to such: well, follows, result, serve, regarded, classified, cited, seen,
# Nearest to would: will, could, might, should, must, can, may, cannot,
# Nearest to most: particularly, more, less, many, best, highly, some, especially,
# Nearest to also: actually, currently, when, which, often, still, below, now,
# Nearest to by: among, when, lir, toward, through, eli, checksum, without,
# Nearest to a: another, any, the, polio, something, jarry, equivocation, expanse,
# Nearest to no: nothing, any, little, another, tatra, secant, neither, rance,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# Some clusters are less obvious (like the standalone characters), but it clearly totaly works!
# How does your CBOW model perform compared to the given Word2Vec model? (to be answered)
# At the first sight, they look similar. The CBOW is a more compact.
